# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c87870be-091d-40b4-bd4d-aa818186c0af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c87870be-091d-40b4-bd4d-aa818186c0af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Test.csv to Test.csv
# Saving Train.csv to Train.csv
# {'Test.csv': b'area_type,availability,location,size,society,total_sqft,bath,balcony,price\r\nSuper built-up  Area,Ready To Move,Brookefield,2 BHK,Roeekbl,1225,2,2,\r\nPlot  Area,Ready To Move,Akshaya Nagar,9 Bedroom,,2400,9,2,\r\nPlot  Area,18-Apr,Hennur Road,4 Bedroom,Saandtt,1650,5,2,\r\nSuper built-up  Area,Ready To Move,Kodichikkanahalli,3 BHK,Winerri,1322,3,1,\r\nSuper built-up  Area,Ready To Move,Konanakunte,2 BHK,AmageSa,1161,2,1,\r\nPlot  Area,Ready To Move,5th Phase JP Nagar,4 Bedroom,,760,3,1,\r\nBuilt-up  Area,Ready To Move,Vijayanagar,4 Bedroom,,4500,4,1,\r\nBuilt-up  Area,Ready To Move,BEML Layout,2 BHK,G aceer,960,2,0,\r\nSuper built-up  Area,Ready To Move,Thanisandra,3 BHK,Soitya ,1569,3,1,\r\nBuilt-up  Area,Ready To Move,NRI Layout,3 BHK,,2400,4,,\r\nSuper built-up  Area,Ready To Move,Hennur Road,3 BHK,Maity W,1445,3,2,\r\nPlot  Area,Ready To Move,Sarjapur,4 Bedroom,Maensar,1505,3,2,\r\nSuper built-up  Area,Ready To Move,Thigalarapalya,4 BHK,Prtanha,3122,6,2,\r\nSuper built-up  Area,Ready To Move,Hennur Road,2 BHK,Gaodsch,1096,2,1,\r\nBuilt-up  Area,Ready To Move,Kanakapura,3 BHK,,1450,3,1,\r\nPlot  Area,Ready To Move,Narayanapura,9 Bedroom,,2884,10,2,\r\nSuper built-up  Area,Ready To Move,Magadi Road,1 BHK,Vrenty ,604,1,1,\r\nSuper built-up  Area,Ready To Move,Kogilu,2 BHK,,1170,2,2,\r\nSuper built-up  Area,Ready To Move,BTM 2nd Stage,2 BHK,,957,2,0,\r\nPlot  Area,Ready To Move,Hebbal Kempapura,3 Bedroom,,2900,4,3,\r\nBuilt-up  Area,18-Dec,Electronic City,2 BHK,,1160,2,1,\r\nBuilt-up  Area,18-Jul,Hosa Road,3 BHK,Mahesr ,1725,3,1,\r\nPlot  Area,Ready To Move,Kengeri Satellite Town Stage 1,1 Bedroom,,450,2,0,\r\nSuper built-up  Area,Ready To Move,Begur Road,3 BHK,Dhalsh ,1500,2,3,\r\nSuper built-up  Area,Ready To Move,Harlur,3 BHK,SrEndPo,1824,3,2,\r\nSuper built-up  Area,Ready To Move,Rachenahalli,3 BHK,Leino C,2250,3,2,\r\nBuilt-up  Area,Ready To Move,Ayappa Nagar,3 BHK,Kuave E,1698,3,1,\r\nSuper built-up  Area,18-Jul,Electronic City,3 BHK,,1400,3,2,\r\nBuilt-up  Area,Ready To Move,Whitefield,2 BHK,,1200,2,1,\r\nSuper built-up  Area,Ready To Move,Dasarahalli,3 BHK,Sooneoo,1902.55,3,2,\r\nCarpet  Area,Ready To Move,JP Nagar,2 BHK,BSensth,1150,2,1,\r\nSuper built-up  Area,Ready To Move,Sarjapur  Road,2 BHK,Contsci,1430,2,2,\r\nPlot  Area,Ready To Move,Kammagondahalli,1 Bedroom,,1215,2,0,\r\nBuilt-up  Area,Ready To Move,Jalahalli,4 BHK,Tahtsla,3083,4,2,\r\nBuilt-up  Area,18-Dec,Electronic City,2 BHK,,1025,2,1,\r\nPlot  Area,Ready To Move,Marathahalli,2 Bedroom,,1353,2,0,\r\nPlot  Area,Ready To Move,Whitefield,5 Bedroom,,6369,4,,\r\nSuper built-up  Area,Ready To Move,Whitefield,2 BHK,Niborik,1085,2,1,\r\nPlot  Area,Ready To Move,4th Block Koramangala,2 Bedroom,,1200,2,1,\r\nSuper built-up  Area,19-Dec,Hoodi,2 BHK,Caycend,1289,2,2,\r\nPlot  Area,Ready To Move,Horamavu Agara,5 Bedroom,,1200,4,1,\r\nSuper built-up  Area,Ready To Move,Hennur Road,3 BHK,,2300,3,3,\r\nSuper built-up  Area,Ready To Move,Sarjapur  Road,3 BHK,Klark L,1691 - 2170,3,0,\r\nSuper built-up  Area,Ready To Move,Hulimavu,2 BHK,NiarkHy,1021,2,2,\r\nSuper built-up  Area,Ready To Move,Frazer Town,3 BHK,Asareur,1750,3,3,\r\nSuper built-up  Area,Ready To Move,Vittasandra,2 BHK,Prlla C,1404,2,2,\r\nSuper built-up  Area,Ready To Move,KR Puram,2 BHK,,1060,2,1,\r\nSuper built-up  Area,Ready To Move,"C P Cassia Apartment,",2 BHK,,1029,1,2,\r\nBuilt-up  Area,Ready To Move,Neeladri Nagar,2 BHK,,850,2,3,\r\nBuilt-up  Area,19-Oct,Whitefield,4 Bedroom,,3565,4,1,\r\nSuper built-up  Area,18-Dec,Whitefield,3 BHK,Prtates,2134,4,2,\r\nSuper built-up  Area,Ready To Move,Thanisandra,3 BHK,Soitya ,1703,3,3,\r\nSuper built-up  Area,Ready To Move,CV Raman Nagar,2 BHK,Srshq T,1190,2,1,\r\nPlot  Area,17-Dec,Hennur Road,3 Bedroom,,700,3,1,\r\nSuper built-up  Area,Ready To Move,Subramanyapura,2 BHK,Prldsri,929,2,2,\r\nSuper built-up  Area,18-May,Bommasandra,2 BHK,SSestth,955,2,1,\r\nPlot  Area,Ready To Move,Koramangala,5 Bedroom,,2400,4,2,\r\nPlot  Area,19-Dec,Tumkur Road,4 B ...
#  'Train.csv': b'area_type,availability,location,size,society,total_sqft,bath,balcony,price\r\nSuper built-up  Area,19-Dec,Electronic City Phase II,2 BHK,Coomee ,1056,2,1,39.07\r\nPlot  Area,Ready To Move,Chikka Tirupathi,4 Bedroom,Theanmp,2600,5,3,120\r\nBuilt-up  Area,Ready To Move,Uttarahalli,3 BHK,,1440,2,3,62\r\nSuper built-up  Area,Ready To Move,Lingadheeranahalli,3 BHK,Soiewre,1521,3,1,95\r\nSuper built-up  Area,Ready To Move,Kothanur,2 BHK,,1200,2,1,51\r\nSuper built-up  Area,Ready To Move,Whitefield,2 BHK,DuenaTa,1170,2,1,38\r\nSuper built-up  Area,18-May,Old Airport Road,4 BHK,Jaades ,2732,4,,204\r\nSuper built-up  Area,Ready To Move,Rajaji Nagar,4 BHK,Brway G,3300,4,,600\r\nSuper built-up  Area,Ready To Move,Marathahalli,3 BHK,,1310,3,1,63.25\r\nPlot  Area,Ready To Move,Gandhi Bazar,6 Bedroom,,1020,6,,370\r\nSuper built-up  Area,18-Feb,Whitefield,3 BHK,,1800,2,2,70\r\nPlot  Area,Ready To Move,Whitefield,4 Bedroom,Prrry M,2785,5,3,295\r\nSuper built-up  Area,Ready To Move,7th Phase JP Nagar,2 BHK,Shncyes,1000,2,1,38\r\nBuilt-up  Area,Ready To Move,Gottigere,2 BHK,,1100,2,2,40\r\nPlot  Area,Ready To Move,Sarjapur,3 Bedroom,Skityer,2250,3,2,148\r\nSuper built-up  Area,Ready To Move,Mysore Road,2 BHK,PrntaEn,1175,2,2,73.5\r\nSuper built-up  Area,Ready To Move,Bisuvanahalli,3 BHK,Prityel,1180,3,2,48\r\nSuper built-up  Area,Ready To Move,Raja Rajeshwari Nagar,3 BHK,GrrvaGr,1540,3,3,60\r\nSuper built-up  Area,Ready To Move,Ramakrishnappa Layout,3 BHK,PeBayle,2770,4,2,290\r\nSuper built-up  Area,Ready To Move,Manayata Tech Park,2 BHK,,1100,2,2,48\r\nBuilt-up  Area,Ready To Move,Kengeri,1 BHK,,600,1,1,15\r\nSuper built-up  Area,19-Dec,Binny Pete,3 BHK,She 2rk,1755,3,1,122\r\nPlot  Area,Ready To Move,Thanisandra,4 Bedroom,Soitya ,2800,5,2,380\r\nSuper built-up  Area,Ready To Move,Bellandur,3 BHK,,1767,3,1,103\r\nSuper built-up  Area,18-Nov, Thanisandra,1 RK,Bhe 2ko,510,1,0,25.25\r\nSuper built-up  Area,18-May,Mangammanapalya,3 BHK,,1250,3,2,56\r\nSuper built-up  Area,Ready To Move,Electronic City,2 BHK,Itelaa ,660,1,1,23.1\r\nBuilt-up  Area,20-Dec,Whitefield,3 BHK,,1610,3,2,81\r\nSuper built-up  Area,17-Oct,Ramagondanahalli,2 BHK,ViistLa,1151,2,2,48.77\r\nSuper built-up  Area,Ready To Move,Electronic City,3 BHK,KBityo ,1025,2,1,47\r\nSuper built-up  Area,19-Dec,Yelahanka,4 BHK,LedorSa,2100 - 2850,4,0,186\r\nSuper built-up  Area,Ready To Move,Bisuvanahalli,3 BHK,Prityel,1075,2,1,35\r\nSuper built-up  Area,Ready To Move,Hebbal,3 BHK,Mahosya,1760,2,2,123\r\nSuper built-up  Area,Ready To Move,Raja Rajeshwari Nagar,3 BHK,GrrvaGr,1693,3,3,57.39\r\nBuilt-up  Area,Ready To Move,Kasturi Nagar,3 BHK,Kantsce,1925,3,,125\r\nSuper built-up  Area,21-Dec,Kanakpura Road,2 BHK,PrarePa,700,2,1,36\r\nSuper built-up  Area,Ready To Move,Electronics City Phase 1,2 BHK,,1070,2,1,45.5\r\nSuper built-up  Area,Ready To Move,Kundalahalli,3 BHK,Dieldli,1724,3,2,125\r\nSuper built-up  Area,Ready To Move,Chikkalasandra,3 BHK,,1290,2,2,56.12\r\nBuilt-up  Area,Ready To Move,Uttarahalli,2 BHK,,1143,2,2,45\r\nBuilt-up  Area,Ready To Move,Murugeshpalya,2 BHK,Gentson,1296,2,,81\r\nSuper built-up  Area,19-Dec,Sarjapur  Road,3 BHK,Soini T,1254,3,2,38\r\nSuper built-up  Area,Ready To Move,Ganga Nagar,1 BHK,Ceove G,600,1,0,38\r\nPlot  Area,Ready To Move,Yelahanka,1 Bedroom,,660,1,0,48\r\nSuper built-up  Area,19-Sep,Kanakpura Road,2 BHK,Soazak ,1330.74,2,2,91.79\r\nPlot  Area,Ready To Move,HSR Layout,8 Bedroom,,600,9,,200\r\nSuper built-up  Area,Ready To Move,Doddathoguru,2 BHK,LancyRe,970,2,0,33\r\nSuper built-up  Area,20-Sep,Whitefield,2 BHK,Goted U,1459,2,1,94.82\r\nPlot  Area,Ready To Move,KR Puram,2 Bedroom,,800,1,1,130\r\nBuilt-up  Area,Ready To Move,Himagiri Meadows,2 BHK,,869,2,1,36\r\nSuper built-up  Area,Ready To Move,Adarsh Nagar,2 BHK,Bhncyis,1270,2,1,50\r\nSuper built-up  Area,18-Mar,Bhoganhalli,3 BHK,Rosha I,1670,3,1,99\r\nBuilt-up  Area,Ready To Move,Whitefield,3 BHK,Suent V,2010,3,2,91\r\nSuper built-up  Area,Ready To Move,Lakshminarayana Pura,2 BHK,R ...

# %%
import re
import pandas as pd
import numpy as np
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('Train.csv')

# %%
display(data.shape)
data.head()
# Out:
# (13320, 9)
#               area_type   availability  ... balcony   price
# 0  Super built-up  Area         19-Dec  ...     1.0   39.07
# 1            Plot  Area  Ready To Move  ...     3.0  120.00
# 2        Built-up  Area  Ready To Move  ...     3.0   62.00
# 3  Super built-up  Area  Ready To Move  ...     1.0   95.00
# 4  Super built-up  Area  Ready To Move  ...     1.0   51.00
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
#Dont think availability will have any impact on the price of a house so Dropping the column availabitity
data.drop(labels=['availability'],axis = 1,inplace = True)
data['balcony'] = data['balcony'].fillna(0)

# %%
data.head()
# Out:
#               area_type                  location  ... balcony   price
# 0  Super built-up  Area  Electronic City Phase II  ...     1.0   39.07
# 1            Plot  Area          Chikka Tirupathi  ...     3.0  120.00
# 2        Built-up  Area               Uttarahalli  ...     3.0   62.00
# 3  Super built-up  Area        Lingadheeranahalli  ...     1.0   95.00
# 4  Super built-up  Area                  Kothanur  ...     1.0   51.00
#
# [5 rows x 8 columns]

# %%
data['size'] = data['size'].fillna('0 BHK')

# %%
size = []
for _,val in enumerate(data['size']):
  size.append(int(val.split()[0]))
data['size'] = np.array(size)
data['size'].replace(0,np.median(data['size']))
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: size, Length: 13320, dtype: int64

# %%
sns.regplot(x = data['size'],y = data['price'] ,scatter=True)

# %%
#size has no great on price linearly
area = []
for _,val in enumerate(data['total_sqft']):
  area_arr = list(map(float,re.findall(r'\d+(?:\.\d+)?',val)))
  if len(area_arr) > 0:
    area.append(np.mean(area_arr))
  else:area.append(area_arr[0])

data['total_sqft'] = np.array(area)

# %%
sns.regplot(x = area,y = data['price'] ,scatter=True)

# %%
sns.scatterplot(x = data['balcony'],y = data['price'])

# %%
#the more the balcony the more the range of price

# %%
sns.scatterplot(x = data['total_sqft'],y = data['price'])

# %%
display(data['area_type'].nunique())
display(data['society'].nunique())
display(data['location'].nunique())
# Out:
# 4
# 2688
# 1305

# %%
data = pd.concat([pd.get_dummies(data=data['area_type'],drop_first = True),data],axis = 1,)
data.drop(labels= ['area_type'],axis = 1,inplace= True)

# %%
dict_society = Counter(data['society'])
dict_location = Counter(data['location'])

# %%
for idx,val in enumerate(data['society']):
  data['society'][idx] = dict_society[val]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data['society'].notnull().sum()
# Out:
# 13320

# %%
data['location'].fillna(0)

for idx,val in enumerate(data['location']):
  data['location'][idx] = dict_location[val]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Carpet  Area          13320 non-null  uint8
#  1   Plot  Area            13320 non-null  uint8
#  2   Super built-up  Area  13320 non-null  uint8
#  3   location              13320 non-null  object
#  4   size                  13320 non-null  int64
#  5   society               13320 non-null  object
#  6   total_sqft            13320 non-null  float64
#  7   bath                  13247 non-null  float64
#  8   balcony               13320 non-null  float64
#  9   price                 13320 non-null  float64
# dtypes: float64(4), int64(1), object(2), uint8(3)
# memory usage: 767.6+ KB

# %%
data['bath'].fillna(np.mean(data['bath']),inplace = True)

# %%
X = data.iloc[:,0:9].values
Y = data.iloc[:,9:10].values

# %%
#Preprocessing version 1 completed

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

linear_regressor = LinearRegression()
decision_tree = DecisionTreeRegressor(random_state = 0)
random_forest = RandomForestRegressor(n_estimators = 200,random_state = 0,n_jobs=2,min_samples_split=6)

X_train,X_val,Y_train,Y_val = train_test_split(X,Y,test_size = 0.2)
linear_regressor.fit(X_train,Y_train)
prediction = linear_regressor.predict(X_val)

# %%
print(mean_absolute_error(Y_val,prediction))
# Out:
# 44.22235070003362

# %%
decision_tree.fit(X_train,Y_train)
tree_prediction = decision_tree.predict(X_val)
print(mean_absolute_error(Y_val,tree_prediction))
# Out:
# 41.098328713883866

# %%
random_forest.fit(X_train,Y_train)
forest_prediction = random_forest.predict(X_val)
print(np.sqrt(np.square(np.log10(forest_prediction +1) - np.log10(Y_val +1)).mean()))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# 0.4282279339228236

# %%
#Data Preprocessing for test_data
test_data = pd.read_csv('Test.csv')

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1480 entries, 0 to 1479
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     1480 non-null   object
#  1   availability  1480 non-null   object
#  2   location      1480 non-null   object
#  3   size          1478 non-null   object
#  4   society       854 non-null    object
#  5   total_sqft    1480 non-null   object
#  6   bath          1473 non-null   float64
#  7   balcony       1411 non-null   float64
#  8   price         0 non-null      float64
# dtypes: float64(3), object(6)
# memory usage: 104.2+ KB

# %%
test_data.drop(labels=['availability'],axis = 1,inplace = True)
test_data['balcony'] = test_data['balcony'].fillna(0)

test_data['size'] = test_data['size'].fillna('0 BHK')

size = []
for _,val in enumerate(test_data['size']):
  size.append(int(val.split()[0]))
test_data['size'] = np.array(size)
test_data['size'].replace(0,np.median(test_data['size']))

area = []
for _,val in enumerate(test_data['total_sqft']):
  area_arr = list(map(float,re.findall(r'\d+(?:\.\d+)?',val)))
  if len(area_arr) > 0:
    area.append(np.mean(area_arr))
  else:area.append(area_arr[0])

test_data['total_sqft'] = np.array(area)


test_data = pd.concat([pd.get_dummies(data=test_data['area_type'],drop_first = True),test_data],axis = 1)
test_data.drop(labels= ['area_type'],axis = 1,inplace= True)

dict_society = Counter(test_data['society'])
dict_location = Counter(test_data['location'])


for idx,val in enumerate(test_data['society']):
  test_data['society'][idx] = dict_society[val]

test_data['location'].fillna(0)

for idx,val in enumerate(test_data['location']):
  test_data['location'][idx] = dict_location[val]

test_data['bath'].fillna(np.mean(test_data['bath']),inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1480 entries, 0 to 1479
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Carpet  Area          1480 non-null   uint8
#  1   Plot  Area            1480 non-null   uint8
#  2   Super built-up  Area  1480 non-null   uint8
#  3   location              1480 non-null   object
#  4   size                  1480 non-null   int64
#  5   society               1480 non-null   object
#  6   total_sqft            1480 non-null   float64
#  7   bath                  1480 non-null   float64
#  8   balcony               1480 non-null   float64
#  9   price                 0 non-null      float64
# dtypes: float64(4), int64(1), object(2), uint8(3)
# memory usage: 85.4+ KB

# %%
model = random_forest = RandomForestRegressor(n_estimators = 200,random_state = 0,n_jobs=2,min_samples_split=6)
model.fit(X,Y)
test_submit = test_data.iloc[:,0:9].values
predictions = model.predict(test_submit)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
np.sqrt(np.square(np.log10(y_pred +1) - np.log10(y_true +1)).mean())
# Out:
# array([ 75.69406016, 392.89869647, 275.32524111, ...,  57.88686915,
#         44.03077935,  62.05189113])

# %%
output = pd.DataFrame({'price':predictions})
output.to_csv('submission.csv', index=False)

# %%
from google.colab import files
files.download('submission.csv')
